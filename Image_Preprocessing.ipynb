# %% [markdown]
# <a href="https://colab.research.google.com/github/VTN02/Artificial-Intelligence-/blob/main/Image_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Libraries that can be used for image preprocessing
#
# 1. matplotlib
# 2. Pillow
# 3. OpenCV (cv2)

# %%
# Importing the image module from matplotlib library
import matplotlib.image as npimg
import matplotlib.pyplot as plt

# %%
# Loading an image through matplotlib.image module
img = npimg.imread('/content/images.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (183, 275, 3)

# %%
print(img)
# Out:
# [[[224 225 229]
#   [224 225 229]
#   [224 225 229]
#   ...
#   [158 154 143]
#   [158 152 140]
#   [155 149 137]]
#
#  [[224 225 229]
#   [224 225 229]
#   [224 225 229]
#   ...
#   [153 146 136]
#   [151 145 133]
#   [148 142 130]]
#
#  [[223 224 228]
#   [223 224 228]
#   [223 224 228]
#   ...
#   [144 138 126]
#   [143 135 122]
#   [140 132 119]]
#
#  ...
#
#  [[ 93  98  34]
#   [ 93  95  32]
#   [ 90  90  28]
#   ...
#   [ 94  91  40]
#   [ 94  91  40]
#   [ 94  91  40]]
#
#  [[ 93  98  34]
#   [ 90  95  31]
#   [ 89  91  28]
#   ...
#   [ 93  90  39]
#   [ 93  90  39]
#   [ 94  91  40]]
#
#  [[ 95 100  36]
#   [ 92  97  33]
#   [ 90  92  29]
#   ...
#   [ 94  90  42]
#   [ 94  90  42]
#   [ 94  90  42]]]

# %%
# Displaying the image from numpy array
img_plot = plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Resizing the Image using pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/images.jpeg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# Displaying the image from nparray

img_res = npimg.imread('/content/dog_image_resized.jpg')
img_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# Converting RGB images to GrayScale image using OpenCV

# %%
# Importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/images.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
from google.colab.patches import cv2_imshow

# %%
# Displayin the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
# Saving the grayscale image
cv2.imwrite('dog_gray_image.jpg', grayscale_image)
# Out:
# True
